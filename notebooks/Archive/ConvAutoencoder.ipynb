# %%
import os
import numpy as np
import random
import tensorflow as tf
import pathlib
import pickle
import matplotlib.pyplot as plt
from tensorflow.keras import backend as K
from tensorflow.keras import layers, losses, activations, callbacks, optimizers
from keras.layers.experimental import preprocessing
from tensorflow.keras.models import load_model
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
              tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)

# %%
print(tf.__version__)
BATCH_SIZE = 32
EPOCHS = 10
# Out:
# 2.3.1

# %%
data_path = '../data'
images_dir = pathlib.Path(f'{data_path}/images')
class_names = np.array(sorted([item.name for item in images_dir.glob('*') if item.name != ".gitkeep" and item.name != ".ipynb_checkpoints"]))
print(class_names)
with open(os.path.join(data_path, 'specs.pickle'), 'rb') as f:
    spec_conv, spec_ae = pickle.load(f)

def load(name, spec):
    out_path = os.path.join(data_path, name)
    if not os.path.exists(out_path):
        raise Exception('Path does not exist')
    return tf.data.experimental.load(out_path, spec)
# Out:
# ['bad' 'good']

# %%
ae_train_ds = load('ae_train_ds', spec_ae)
ae_val_ds = load('ae_val_ds', spec_ae)
conv_train_ds = load('conv_train_ds', spec_conv)
conv_val_ds = load('conv_val_ds', spec_conv)

image_batch, label_batch = next(iter(conv_val_ds))
X_batch, _ = next(iter(ae_val_ds))

def plot_conv_ds(image_batch, label_batch):
    fig = plt.figure(figsize=(10, 10))
    fig.suptitle('Conv DS', fontsize=20)
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        label = label_batch[i]
        plt.title(class_names[label])
        plt.axis("off")

def plot_ae_ds(image_batch):
    fig = plt.figure(figsize=(10, 10))
    fig.suptitle('AE DS', fontsize=20)
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.axis("off")

plot_conv_ds(image_batch, label_batch)
plot_ae_ds(X_batch)

# %% [markdown]
# # Autoencoder

# %%
class Autoencoder():
    @staticmethod
    def build(width, height, depth, filters=[128,64,32,16], latent_dim=100): #HIL: check with first filter 256 to also get smaller impurities?
        input_shape = (height, width, depth)
        chan_dim = -1
        
        
        inputs = layers.Input(shape=input_shape)
        x = inputs
            
            
        # Rescale from [0,255] to [-1,1]
        x = preprocessing.Rescaling(scale=1./255, 
                            #offset=-1,
                            name='Preprocessing_Rescale'
                           )(x) # Rescale values from [0,255] to [0,1] see https://www.tensorflow.org/api_docs/python/tf/keras/layers/experimental/preprocessing/Rescaling


        
        for f in filters:
            x = layers.Conv2D(f, (3, 3), strides=2, padding="same")(x)
            x = layers.LeakyReLU()(x)
                
        volume_size = K.int_shape(x)
        x = layers.Flatten()(x)
        latent = layers.Dense(latent_dim)(x)
        
        # build the encoder model
        encoder = tf.keras.Model(inputs, latent, name="encoder")
        latent_inputs = layers.Input(shape=(latent_dim,))
        x = layers.Dense(np.prod(volume_size[1:]))(latent_inputs)
        x = layers.Reshape((volume_size[1], volume_size[2], volume_size[3]))(x)
        for i, f in enumerate(filters[::-1]):
            x = layers.Conv2DTranspose(f, (3, 3), strides=2, padding="same")(x)
            
            if i < len(filters) - 1:
                x = layers.LeakyReLU()(x)
            
        x = layers.Conv2D(3, kernel_size=(3,3), activation='sigmoid', padding='same')(x)
        
        outputs = preprocessing.Rescaling(scale=255.0, name='Postprocessing_Rescale')(x)
        
        # build the decoder model
        decoder = tf.keras.Model(latent_inputs, outputs, name="decoder")
        
        # build the autoencoder model
        autoencoder = tf.keras.Model(inputs, decoder(encoder(inputs)),
            name="autoencoder")
        
        return (encoder, decoder, autoencoder)
        

encoder, decoder, autoencoder = Autoencoder.build(256, 256, 3, [128,64,32,16])
encoder.summary()
decoder.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# Preprocessing_Rescale (Resca (None, 256, 256, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 128, 128, 128)     3584
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 128, 128, 128)     0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 64)        73792
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        18464
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 16)        4624
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 16, 16, 16)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 100)               409700
# =================================================================
# Total params: 510,164
# Trainable params: 510,164
# Non-trainable params: 0
# _________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              413696
# _________________________________________________________________
# reshape (Reshape)            (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 32, 32, 16)        2320
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 64, 64, 32)        4640
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 128, 128, 64)      18496
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 256, 256, 128)     73856
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 256, 256, 3)       3459
# _________________________________________________________________
# Postprocessing_Rescale (Resc (None, 256, 256, 3)       0
# =================================================================
# Total params: 516,467
# Trainable params: 516,467
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = optimizers.Adam(lr=1e-3)

#def root_mean_squared_error(y_true, y_pred):
#        return K.sqrt(K.mean(K.square(y_pred - y_true))) 
    
ls = losses.MeanSquaredError() 
autoencoder.compile(optimizer=opt, loss=ls, metrics=['accuracy'])

# %%
from datetime import datetime

timestamp = datetime.now().isoformat()
outpath = os.path.join('..', 'log')
def get_callbacks():
        tensorboard_dir = os.path.join(outpath, f'tensorboard')
        if not os.path.exists(tensorboard_dir):
            os.makedirs(tensorboard_dir)
        tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=tensorboard_dir, histogram_freq=1)
        
        metrics_dir = os.path.join(outpath, f'metrics')
        if not os.path.exists(metrics_dir):
            os.makedirs(metrics_dir)
        csv_callback = tf.keras.callbacks.CSVLogger(filename=os.path.join(metrics_dir, f'training_log_{timestamp}.csv'))
        
        checkpoint_dir = os.path.join(outpath, f'checkpoints')
        if not os.path.exists(checkpoint_dir):
            os.makedirs(checkpoint_dir)
        checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(verbos=0, 
            filepath=os.path.join(checkpoint_dir, 'weights.{epoch:02d}-{val_accuracy:.2f}-{val_loss:.2f}.hdf5'),
            save_weights_only=True,
            monitor='val_loss',
            mode='auto',
            save_best_only=True,
            save_freq='epoch')

        reduce_lr_plateau_callback = tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss', 
            factor=0.5, 
            patience=3, 
            min_lr=0.00001)

        return [tensorboard_callback, csv_callback, checkpoint_callback, reduce_lr_plateau_callback]

# %%
history = autoencoder.fit(ae_train_ds,
                epochs=EPOCHS,
                batch_size=BATCH_SIZE,
                validation_data=ae_val_ds,
                shuffle=True,
                callbacks=get_callbacks())
# Out:
# Epoch 1/10
# 49/49 [==============================] - 451s 9s/step - loss: 2651.2092 - accuracy: 0.3082 - val_loss: 1254.7731 - val_accuracy: 0.3403
# Epoch 2/10
# 49/49 [==============================] - 444s 9s/step - loss: 750.9804 - accuracy: 0.2865 - val_loss: 511.1512 - val_accuracy: 0.3729
# Epoch 3/10
# 49/49 [==============================] - 436s 9s/step - loss: 324.8586 - accuracy: 0.3573 - val_loss: 339.1469 - val_accuracy: 0.3663
# Epoch 4/10
# 49/49 [==============================] - 437s 9s/step - loss: 210.9346 - accuracy: 0.3508 - val_loss: 223.6721 - val_accuracy: 0.3644
# Epoch 5/10
# 49/49 [==============================] - 413s 8s/step - loss: 182.4222 - accuracy: 0.3449 - val_loss: 181.6130 - val_accuracy: 0.3513
# Epoch 6/10
# 49/49 [==============================] - 410s 8s/step - loss: 155.3884 - accuracy: 0.3410 - val_loss: 161.1685 - val_accuracy: 0.3430
# Epoch 7/10
# 49/49 [==============================] - 424s 9s/step - loss: 146.2507 - accuracy: 0.3392 - val_loss: 150.6548 - val_accuracy: 0.3378
# Epoch 8/10
# 49/49 [==============================] - 410s 8s/step - loss: 135.6177 - accuracy: 0.3383 - val_loss: 148.1980 - val_accuracy: 0.3352
# Epoch 9/10
# 49/49 [==============================] - 395s 8s/step - loss: 130.1658 - accuracy: 0.3381 - val_loss: 141.2963 - val_accuracy: 0.3372
# Epoch 10/10
# 49/49 [==============================] - 388s 8s/step - loss: 126.1302 - accuracy: 0.3382 - val_loss: 136.7912 - val_accuracy: 0.3377

# %%
plot_dir = os.path.join(outpath, f'plots')
if not os.path.exists(plot_dir):
    os.makedirs(plot_dir)
def plot_accuracy(hist):
    plt.clf()
    plt.figure(figsize=(10,10))
    title = f"Accuracy"
    plt.plot(hist.history["accuracy"])
    plt.plot(hist.history["val_accuracy"])
    plt.title(title)
    plt.ylabel("accuracy")
    plt.xlabel("epoch")
    plt.legend(["train", "validation"], loc="lower right")
    plt.show(block=False)
    plt.savefig(os.path.join(plot_dir, f'accuracy_{timestamp}.png'))

def plot_loss(hist):
    plt.clf()
    plt.figure(figsize=(10,10))
    title = f"Loss"
    plt.plot(hist.history["loss"])
    plt.plot(hist.history["val_loss"])
    plt.title(title)
    plt.ylabel("loss")
    plt.xlabel("epoch")
    plt.legend(["train", "validation"], loc="upper right")
    plt.show(block=False)
    plt.savefig(os.path.join(plot_dir, f'loss_{timestamp}.png'))
    
def plot_metrics(history, metrics):
    if 'accuracy' in metrics:
        plot_accuracy(hist=history)
    if 'loss' in metrics:
        plot_loss(hist=history)
        
plot_metrics(history, ['accuracy', 'loss'])

# %%
model_save_dir = os.path.join(outpath, f'model')
if not os.path.exists(model_save_dir):
    os.makedirs(model_save_dir)
autoencoder.save(os.path.join(model_save_dir, timestamp))
# Out:
# INFO:tensorflow:Assets written to: ../log/model/2020-11-19T17:58:11.158397/assets

# %%
  
def visualize(img,encoder,decoder):
    """Draws original, encoded and decoded images"""
    
    code = encoder.predict(img)[0]
    reco = decoder.predict(code)[0]

    plt.subplot(1,3,1)
    plt.title("Original")
    plt.imshow(tf.squeeze(img))

    plt.subplot(1,3,2)
    plt.title("Code")
    plt.imshow(code.reshape([code.shape[-1]//2,-1]))

    plt.subplot(1,3,3)
    plt.title("Reconstructed")
    plt.imshow(tf.squeeze(reco))
    plt.show()

# %%
image_batch, _ = next(iter(ae_val_ds))
#load model
#ae = load_model('../log/model/2020-11-19T17:58:11.158397')
#ae.save_weights('../ckpts/convae_weights')

# load weights saved from model '../log/model/2020-11-19T17:58:11.158397'
autoencoder.load_weights('../ckpts/convae_weights')

code = encoder.predict(image_batch)
reco = decoder.predict(code)


titles = ['Original', 'Code', 'Reconstructed']
fig, ax = plt.subplots(nrows=9, ncols=3,figsize=(10,25))
for i, row in enumerate(ax):
    # Original
    row[0].set_title(titles[0])
    row[0].imshow(image_batch[i].numpy().astype("uint8"))
    row[0].axis("off")
    
    # Code
    row[1].set_title(titles[1])
    row[1].imshow(code[i].reshape([code.shape[-1]//10,-1]).astype("uint8"))
    row[1].axis("off")
    
    # Reconstructed
    row[2].set_title(titles[2])
    row[2].imshow(reco[i].astype("uint8"))
    row[2].axis("off")
